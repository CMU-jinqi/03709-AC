# %%
import matplotlib.pyplot as plt

# Same dataset
methods = ["Full", "AF2-only", "Filters-only"]
success_rate_alt = [70, 68, 65]

plt.figure(figsize=(6, 4), facecolor="white")  
bars = plt.bar(methods, success_rate_alt, color=["#4B8BBE", "#FFD43B", "#646464"], edgecolor="none")

plt.title("Alternative Possible Result: Similar Success Rates", fontsize=13, fontweight="bold", pad=15)
plt.xlabel("Design Method", fontsize=11)
plt.ylabel("Success Rate (%)", fontsize=11)
plt.ylim(0, 100)

# same editing
for spine in ["top", "right"]:
    plt.gca().spines[spine].set_visible(False)
plt.grid(False)
plt.tight_layout()
plt.show()

# it should be same
